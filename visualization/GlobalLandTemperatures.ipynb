# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/GlobalLandTemperaturesByCountry.csv')
data['dt'] = pd.to_datetime( data['dt'], format='%Y-%d-%m', errors='ignore' )
data = data[ data['AverageTemperature'].notnull() ]

# %%
data = data[ data['Country'] == 'Iran' ]

# %%
data.tail(10)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty Country
# 250682 2012-01-11              14.051                          0.381    Iran
# 250683 2012-01-12               8.295                          0.397    Iran
# 250684 2013-01-01               7.669                          0.511    Iran
# 250685 2013-01-02               9.867                          0.676    Iran
# 250686 2013-01-03              13.960                          1.354    Iran
# 250687 2013-01-04              18.416                          0.538    Iran
# 250688 2013-01-05              24.123                          0.268    Iran
# 250689 2013-01-06              29.361                          0.376    Iran
# 250690 2013-01-07              31.459                          0.528    Iran
# 250691 2013-01-08              29.473                          0.386    Iran

# %%
g = sns.FacetGrid(data, size=10)
g.map(plt.scatter, "dt", "AverageTemperature", s=30, alpha=.6)
g.add_legend();
